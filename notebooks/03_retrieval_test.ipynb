# %% [markdown]
# # Week 4a — Retrieval sanity check
# Run a few test queries and eyeball whether the right chunks/images come back.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/multimodal-rag-enterprise-km
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/multimodal-rag-enterprise-km

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 78.2 MB/s eta 0:00:00
# ...

# %%
import sys, os
sys.path.append('..')
from dotenv import load_dotenv
load_dotenv('../.env')

from src.indexing import load_indexes
from src.retrieval import retrieve

text_index, image_index, text_metadata, image_metadata = load_indexes('../indexes')
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
query = 'How do I reset the device to factory settings?'
retrieved_texts, retrieved_images, scores = retrieve(query, text_index, image_index, text_metadata, image_metadata, k=3)

for t, s in zip(retrieved_texts, scores['text_scores']):
    print(f"[{s:.3f}] {t['source']} p.{t['page']}: {t['text'][:150]}...")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# /tmp/ipykernel_2642/2152495406.py in <cell line: 0>()
#       1 query = 'How do I reset the device to factory settings?'
# ----> 2 retrieved_texts, retrieved_images, scores = retrieve(query, text_index, image_index, text_metadata, image_metadata, k=3)
#       3
#       4 for t, s in zip(retrieved_texts, scores['text_scores']):
#       5     print(f"[{s:.3f}] {t['source']} p.{t['page']}: {t['text'][:150]}...")
#
# /content/drive/MyDrive/multimodal-rag-enterprise-km/src/retrieval.py in retrieve(query, text_index, image_index, text_metadata, image_metadata, k)
#      18     retrieved_texts, text_scores = [], []
#      19     if text_index.ntotal > 0:
# ---> 20         q_text_vec = embed_text(query, task_type="retrieval_query")
#      21         q_text_vec = q_text_vec / np.linalg.norm(q_text_vec)
# ...

# %%
for i, s in zip(retrieved_images, scores['image_scores']):
    print(f"[{s:.3f}] {i['source']} p.{i['page']}: {i['path']}")

# %%
import sys, os
from dotenv import load_dotenv

# 1. Load credentials and map key name
load_dotenv('.env.txt')
if "GEMINI_API_KEY" in os.environ:
    os.environ["GOOGLE_API_KEY"] = os.environ["GEMINI_API_KEY"]

# 2. Add repo paths and load index modules
sys.path.append('.')
from src.indexing import load_indexes
from src.retrieval import retrieve

# 3. Load newly generated index assets
text_index, image_index, text_metadata, image_metadata = load_indexes('indexes')
print("🎉 Success! Vector indexes loaded completely.")

# 4. Test execution
query = 'How do I reset the device to factory settings?'
retrieved_texts, retrieved_images, scores = retrieve(query, text_index, image_index, text_metadata, image_metadata, k=3)

print(f"\nFound {len(retrieved_texts)} text matches and {len(retrieved_images)} image matches.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2642/677614081.py in <cell line: 0>()
#      13
#      14 # 3. Load newly generated index assets
# ---> 15 text_index, image_index, text_metadata, image_metadata = load_indexes('indexes')
#      16 print("🎉 Success! Vector indexes loaded completely.")
#      17
#
# /content/drive/MyDrive/multimodal-rag-enterprise-km/src/indexing.py in load_indexes(out_dir)
#      32
#      33 def load_indexes(out_dir: str):
# ---> 34     text_index = faiss.read_index(os.path.join(out_dir, "text_index.faiss"))
#      35     image_index = faiss.read_index(os.path.join(out_dir, "image_index.faiss"))
#      36     with open(os.path.join(out_dir, "metadata.pkl"), "rb") as f:
#
# /usr/local/lib/python3.13/dist-packages/faiss/swigfaiss.py in read_index(*args)
#   14021
#   14022 def read_index(*args):
# ...
